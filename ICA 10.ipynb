# %% [markdown]
# <H1>INSTRUCTIONS</H1>

# %% [markdown]
# In this ICA, you will build various text classification models and use them to classify sentences from 2016 presidential debates according to speaker.
#
# The ICA zip file contains three files train, dev and test. The files are one document per line, tokenized and lowercased, so you don't have to do any preprocessing. Each line has the format:
#
#
#    <font color="red"> <center>trump i fully understand .</center></font>
#
# where the first token is the speaker's name, and the remaining tokens are the words of the document.

# %% [markdown]
# <H2>Hands on programming with Text Classification</H2>

# %% [markdown]
# Naive Bayes Classifier with 51.5% accuracy is provided.
# Experiment with two new kinds of features.
# <ol type="a">
# <li>Extend the code provided to construct a bag of words to include an additional kind of feature besides words. You can try bigrams, prefixes, parts of speech, anything you like. Describe your new features. Report your new accuracy. Briefly write down your conclusions from this experiment.<b>(5 points)</b></li>
#     <li>Do the same thing for another kind of feature. Report your new accuracy. Briefly write down your conclusions from this experiment.<b>(5 points)</b></li>
# </ol>

# %%
import pandas as pd
import numpy as np

# %%
##Load Training Data
train_x=[]
train_y=[]

# %%
with open('train.txt', 'r') as f:
   for line in f:
        temp=line.split(' ',1)
        train_x.append(temp[1])
        train_y.append(temp[0])

# %%
np.unique(train_y)
# Out:
# array(['bush', 'carson', 'chafee', 'christie', 'clinton', 'cruz',
#        'fiorina', 'huckabee', 'kasich', "o'malley", 'paul', 'perry',
#        'rubio', 'sanders', 'trump', 'walker', 'webb'], dtype='<U8')

# %%
len(np.unique(train_y))
# Out:
# 17

# %%
train_df = pd.DataFrame({'sentence':train_x, 'speaker':train_y})
train_df.head()
# Out:
#                                             sentence  speaker
# 0  no . i am very proud to be jewish , and being ...  sanders
# 1  well , that just wasn't that just wasn't the f...  clinton
# 2  thank you , anderson . thank you , cnn . and t...   chafee
# 3                . . . let us talk about issues . \n  sanders
# 4                thank you , bernie . thank you . \n  clinton

# %%
##Load test data
test_x=[]
test_y=[]

# %%
with open('test.txt', 'r') as f:
   for line in f:
        temp=line.split(' ',1)
        test_x.append(temp[1])
        test_y.append(temp[0])

# %%
test_df = pd.DataFrame({'sentence':test_x, 'speaker':test_y})
test_df.head()
# Out:
#                                             sentence  speaker
# 0  madam secretary , when he asked me to speak . ...  sanders
# 1  too many lives have been destroyed because peo...  sanders
# 2                          . . . well and i . . . \n  sanders
# 3  look , the secretary is right . this is a terr...  sanders
# 4  well , hillary clinton , and everybody else wh...  sanders

# %% [markdown]
# <H3>Train Naive Bayes Classifier with the data in "train.txt" file</H3>

# %%
#Count of documents per class
from collections import Counter
docs_per_class = Counter(train_df['speaker'])
docs_per_class
# Out:
# Counter({'sanders': 501,
#          'clinton': 455,
#          'chafee': 18,
#          "o'malley": 128,
#          'webb': 28,
#          'bush': 207,
#          'cruz': 273,
#          'trump': 637,
#          'christie': 81,
#          'rubio': 305,
#          'kasich': 162,
#          'fiorina': 90,
#          'paul': 94,
#          'carson': 104,
#          'huckabee': 41,
#          'walker': 31,
#          'perry': 1})

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words="english",ngram_range=(2,2)) 
X_train_dtm = vect.fit_transform(train_df.sentence)

# %%
#count of words for all speakers
vect.vocabulary_
# Out:
# {'proud jewish': 51641,
#  'jewish jewish': 33941,
#  'jewish look': 33942,
#  'look father': 39264,
#  'father family': 23206,
#  'family wiped': 23052,
#  'wiped hitler': 72572,
#  'hitler holocaust': 30072,
#  'holocaust know': 30129,
#  'know crazy': 35582,
#  'crazy radical': 14782,
#  'radical extremist': 52388,
#  'extremist politics': 22395,
#  'politics mean': 49299,
#  'mean learned': 41233,
#  'learned lesson': 37058,
#  'lesson tiny': 37451,
#  'tiny tiny': 66596,
#  'tiny child': 66595,
#  'child mother': 10483,
#  'mother shopping': 42902,
#  'shopping people': 59136,
#  'people working': 47762,
#  'working stores': 73389,
#  'stores numbers': 61789,
#  'numbers arms': 44636,
#  'arms hitler': 4560,
#  'hitler concentration': 30071,
#  'concentration camp': 12729,
#  'camp proud': 8862,
#  'jewish essential': 33940,
#  'essential human': 21478,
#  'just wasn': 34826,
#  'wasn just': 71408,
#  'wasn fact': 71400,
#  'fact senator': 22648,
#  'senator fact': 58519,
#  'fact great': 22589,
#  'great effort': 27748,
#  'effort obama': 20315,
#  'obama administration': 44680,
#  'administration really': 2050,
#  'really send': 53096,
#  'send clear': 58586,
#  'clear message': 11270,
#  'message knew': 41723,
#  'knew children': 35437,
#  'children abused': 10509,
#  'abused treated': 1277,
#  'treated terribly': 67469,
#  'terribly tried': 64830,
#  'tried border': 67556,
#  'border disagreement': 7473,
#  'disagreement think': 18144,
#  'think ve': 65962,
#  've called': 69423,
#  'called counsel': 8657,
#  'counsel child': 13947,
#  'child child': 10458,
#  'child face': 10466,
#  'face kind': 22443,
#  'kind process': 35349,
#  'process speaks': 51029,
#  'speaks advocates': 60288,
#  'advocates child': 2220,
#  'child right': 10491,
#  'right decision': 55459,
#  'decision hopefully': 16382,
#  'thank anderson': 65053,
#  'anderson thank': 3825,
#  'thank cnn': 65062,
#  'cnn thank': 11637,
#  'thank facebook': 65072,
#  'facebook sponsoring': 22468,
#  'sponsoring debate': 60578,
#  'debate america': 16121,
#  'america challenges': 3213,
#  'challenges confronting': 9966,
#  'confronting ending': 12929,
#  'ending perpetual': 20923,
#  'perpetual wars': 48015,
#  'wars addressing': 71229,
#  'addressing climate': 1978,
#  'climate change': 11344,
#  'change addressing': 10038,
#  'addressing income': 1979,
#  'income inequality': 31645,
#  'inequality funding': 31994,
#  'funding education': 25247,
#  'education funding': 20192,
#  'funding infrastructure': 25254,
#  'infrastructure funding': 32089,
#  'funding healthcare': 25252,
#  'healthcare helping': 29346,
#  'helping black': 29722,
#  'black americans': 7207,
#  'americans helping': 3638,
#  'helping native': 29727,
#  'native americans': 43325,
#  'americans challenges': 3607,
#  'challenges best': 9965,
#  'best able': 6604,
#  'able confront': 998,
#  'confront challenges': 12911,
#  'challenges ve': 9977,
#  've served': 69607,
#  'served government': 58819,
#  'government levels': 27366,
#  'levels know': 37716,
#  'know like': 35761,
#  'like solve': 38352,
#  'solve problems': 59931,
#  'problems local': 50915,
#  'local level': 39054,
#  'level did': 37670,
#  'did mayor': 17576,
#  'mayor know': 41156,
#  'know legislation': 35756,
#  'legislation passed': 37384,
#  'passed congress': 46580,
#  'congress did': 12966,
#  'did senator': 17623,
#  'senator know': 58531,
#  'know turn': 35995,
#  'turn state': 68250,
#  'state did': 61130,
#  'did governor': 17527,
#  'governor rhode': 27549,
#  'rhode island': 55283,
#  'island proud': 33342,
#  'proud 30': 51616,
#  '30 years': 636,
#  'years public': 74302,
#  'public service': 51829,
#  'service scandals': 58850,
#  'scandals high': 57652,
#  'high ethical': 29806,
#  'ethical standards': 21528,
#  'standards proud': 60864,
#  'proud judgment': 51644,
#  'judgment particularly': 34446,
#  'particularly iraq': 46381,
#  'iraq war': 33096,
#  'war vote': 71184,
#  'vote lot': 70207,
#  'lot pressure': 39800,
#  'pressure political': 50347,
#  'political pressure': 49187,
#  'pressure public': 50348,
#  'public pressure': 51817,
#  'pressure did': 50342,
#  'did homework': 17541,
#  'homework did': 30229,
#  'did believe': 17457,
#  'believe evidence': 6238,
#  'evidence saddam': 21763,
#  'saddam hussein': 56403,
#  'hussein weapons': 30798,
#  'weapons mass': 72049,
#  'mass destruction': 40925,
#  'destruction live': 17272,
#  'live consequences': 38688,
#  'consequences kind': 13129,
#  'kind judgment': 35321,
#  'judgment want': 34462,
#  'want president': 70842,
#  'president going': 50110,
#  'going forward': 26330,
#  'forward running': 24725,
#  'running president': 56256,
#  'president end': 50081,
#  'end wars': 20889,
#  'wars want': 71248,
#  'want peacemaker': 70828,
#  'peacemaker proven': 46966,
#  'proven peacemaker': 51693,
#  'peacemaker chafee': 46965,
#  'chafee 2016': 9917,
#  '2016 learn': 526,
#  'learn thank': 37043,
#  'let talk': 37628,
#  'talk issues': 63582,
#  'thank bernie': 65059,
#  'bernie thank': 6600,
#  've got': 69491,
#  'got aggressively': 26926,
#  'aggressively normalize': 2443,
#  'normalize relations': 44396,
#  'relations iran': 54132,
#  'iran understanding': 32985,
#  'understanding iran': 68633,
#  'iran behavior': 32898,
#  'behavior ways': 6140,
#  'ways disagree': 71869,
#  'disagree support': 18125,
#  'support terrorism': 62774,
#  'terrorism anti': 64866,
#  'anti american': 3984,
#  'american rhetoric': 3566,
#  'rhetoric hearing': 55279,
#  'hearing leadership': 29474,
#  'leadership acceptable': 36906,
#  'acceptable hand': 1309,
#  'hand fact': 28616,
#  'fact ve': 22672,
#  've managed': 69541,
#  'managed reach': 40606,
#  'reach agreement': 52713,
#  'agreement ve': 2691,
#  've strongly': 69624,
#  'strongly supported': 62254,
#  'supported prevents': 62836,
#  'prevents iran': 50416,
#  'iran getting': 32925,
#  'getting nuclear': 25794,
#  'nuclear weapon': 44527,
#  'weapon did': 72006,
#  'did going': 17525,
#  'going war': 26636,
#  'war believe': 71105,
#  'believe seeing': 6378,
#  'seeing fall': 58247,
#  'fall relationships': 22855,
#  'relationships iran': 54164,
#  'iran positive': 32950,
#  'positive step': 49544,
#  'step question': 61616,
#  'question want': 52209,
#  'want relationship': 70865,
#  'relationship positive': 54154,
#  'positive future': 49536,
#  'future yes': 25352,
#  'yes tell': 74477,
#  'tell open': 64527,
#  'open embassy': 45423,
#  'embassy tehran': 20615,
#  'tehran tomorrow': 64381,
#  'tomorrow don': 66839,
#  'don think': 19263,
#  'think think': 65935,
#  'think goal': 65671,
#  'goal ve': 26031,
#  've cuba': 69440,
#  'cuba warm': 15245,
#  'warm relations': 71207,
#  'relations powerful': 54137,
#  'powerful important': 49789,
#  'important country': 31276,
#  'country world': 14507,
#  'true laughter': 67741,
#  'start providing': 60977,
#  'providing senate': 51765,
#  'look think': 39415,
#  'think saying': 65879,
#  'saying long': 57511,
#  'long ve': 39133,
#  've known': 69519,
#  'known 25': 36056,
#  '25 years': 595,
#  'years doesn': 74216,
#  'doesn change': 18662,
#  'change view': 10146,
#  'view need': 69937,
#  'need empower': 43552,
#  'empower women': 20728,
#  'women men': 72756,
#  'men make': 41621,
#  'make best': 40203,
#  'best decisions': 6620,
#  'decisions minds': 16424,
#  'minds make': 42177,
#  'make ve': 40387,
#  've stood': 69622,
#  'stood comes': 61667,
#  'comes issues': 12064,
#  'issues really': 33712,
#  'really lines': 53061,
#  'lines going': 38491,
#  'going equal': 26294,
#  'equal pay': 21379,
#  'pay paid': 46799,
#  'paid family': 46141,
#  'family leave': 23015,
#  'leave opportunity': 37109,
#  'opportunity know': 45558,
#  'know women': 36032,
#  'women far': 72737,
#  'far hard': 23108,
#  'hard work': 29017,
#  'work talent': 73132,
#  'talent think': 63488,
#  'think barriers': 65545,
#  'barriers knock': 5795,
#  'knock core': 35460,
#  'core campaign': 13691,
#  'campaign note': 8930,
#  'note just': 44421,
#  'just historic': 34653,
#  'historic aside': 29983,
#  'aside somebody': 4642,
#  'somebody told': 60026,
#  'told earlier': 66794,
#  'earlier today': 19746,
#  'today ve': 66761,
#  've like': 69531,
#  'like 200': 38086,
#  '200 presidential': 424,
#  'presidential primary': 50319,
#  'primary debates': 50476,
#  'debates time': 16207,
#  'time majority': 66405,
#  'majority women': 40177,
#  'women stage': 72772,
#  'stage know': 60678,
#  'know ll': 35766,
#  'll progress': 38937,
#  'nikki fair': 44275,
#  'fair question': 22796,
#  'question government': 52140,
#  'levels let': 37717,
#  'let children': 37495,
#  'children people': 10580,
#  'people flint': 47266,
#  'flint think': 24088,
#  'think things': 65934,
#  'things repair': 65457,
#  'repair work': 54370,
#  'work mayor': 73065,
#  'mayor weaver': 41165,
#  'weaver program': 72085,
#  'program support': 51187,
#  'support begin': 62643,
#  'begin help': 6054,
#  'help train': 29686,
#  'train people': 67335,
#  'flint able': 24067,
#  'able work': 1106,
#  'work distribute': 73003,
#  'distribute water': 18428,
#  'water triple': 71531,
#  'triple checked': 67652,
#  'checked regain': 10339,
#  'regain trust': 53871,
#  'trust hold': 67897,
#  'hold responsible': 30096,
#  'responsible fixing': 55024,
#  'fixing pipes': 24012,
#  'pipes delivering': 48321,
#  'delivering clean': 16775,
#  'clean water': 11218,
#  'water said': 71526,
#  'said bathe': 56532,
#  'bathe drink': 5915,
#  'drink wash': 19552,
#  'wash food': 71250,
#  'food run': 24392,
#  'run minds': 56207,
#  'minds use': 42178,
#  'use water': 69130,
#  'water single': 71527,
#  'single day': 59461,
#  'day understand': 15760,
#  'understand pressures': 68568,
#  'pressures real': 50354,
#  'real pain': 52924,
#  'pain families': 46158,
#  'families going': 22916,
#  'going make': 26430,
#  'make sure': 40370,
#  'sure president': 63047,
#  'president double': 50078,
#  'double triple': 19438,
#  'triple check': 67651,
#  'check work': 10337,
#  'work elected': 73011,
#  'elected officials': 20428,
#  'officials trust': 45146,
#  'trust like': 67900,
#  'like mayor': 38255,
#  'mayor like': 41157,
#  'like senators': 38344,
#  'senators member': 58571,
#  'member congress': 41575,
#  'congress assure': 12950,
#  'assure fixed': 4953,
#  'fixed trust': 24002,
#  'trust deserve': 67891,
#  'called changes': 8650,
#  'changes record': 10202,
#  'record toughest': 53564,
#  'toughest comprehensive': 67169,
#  'comprehensive plan': 12703,
#  'plan wall': 48581,
#  'wall street': 70592,
#  'street just': 61983,
#  'just big': 34540,
#  'big banks': 6858,
#  'banks financial': 5706,
#  'financial interests': 23805,
#  'interests pose': 32552,
#  'pose threat': 49448,
#  'threat economy': 66147,
#  'economy said': 20127,
#  'said bank': 56529,
#  'bank big': 5631,
#  'big fail': 6892,
#  'fail executive': 22724,
#  'executive powerful': 22026,
#  'powerful jail': 49793,
#  'jail use': 33778,
#  'use powers': 69108,
#  'powers passed': 49815,
#  'congress president': 13006,
#  'president obama': 50172,
#  'obama incidentally': 44760,
#  'incidentally took': 31535,
#  'took lot': 66981,
#  'lot money': 39780,
#  'money wall': 42722,
#  'street didn': 61947,
#  'didn stop': 17768,
#  'stop signing': 61754,
#  'signing law': 59384,
#  'law toughest': 36634,
#  'toughest regulations': 67174,
#  'regulations financial': 54009,
#  'financial industry': 23802,
#  'industry great': 31949,
#  'great depression': 27741,
#  'running democratic': 56239,
#  'democratic nomination': 16869,
#  'nomination president': 44328,
#  'president united': 50280,
#  'united states': 68844,
#  'states good': 61385,
#  'good point': 26829,
#  'point know': 48845,
#  'know virtually': 36010,
#  'virtually general': 70055,
#  'general election': 25557,
#  'election match': 20487,
#  'match polls': 40972,
#  'polls trump': 49364,
#  'trump secretary': 67853,
#  'secretary clinton': 58003,
#  'clinton trump': 11523,
#  'trump bernie': 67794,
#  'bernie sanders': 6597,
#  'sanders polls': 56949,
#  'polls better': 49344,
#  'better secretary': 6798,
#  'clinton cnn': 11387,
#  'cnn poll': 11632,
#  'poll 20': 49315,
#  '20 points': 414,
#  'points ahead': 48922,
#  'ahead trump': 2755,
#  'trump think': 67862,
#  'think secretary': 65882,
#  'clinton 12': 11357,
#  '12 points': 230,
#  'points know': 48938,
#  'know fact': 35643,
#  'fact lot': 22610,
#  'lot people': 39792,
#  'people shock': 47612,
#  'shock secretary': 59106,
#  'secretary lot': 58026,
#  'lot independents': 39757,
#  'independents country': 31846,
#  'supported know': 62825,
#  'know vigorous': 36009,
#  'vigorous agreement': 69977,
#  'agreement senator': 2681,
#  'don answer': 19060,
#  'answer page': 3941,
#  'page yes': 46119,
#  'yes laughter': 74433,
#  'laughter mean': 36492,
#  'mean seriously': 41262,
#  'seriously know': 58792,
#  'know ve': 36006,
#  've yes': 69670,
#  'yes behavior': 74390,
#  'behavior deplorable': 6129,
#  'deplorable said': 17046,
#  'said word': 56830,
#  'word issue': 72908,
#  'issue going': 33557,
#  'going debate': 26238,
#  'debate secretary': 16174,
#  'clinton governor': 11427,
#  'governor malley': 27533,
#  'malley issues': 40532,
#  'issues facing': 33672,
#  'facing american': 22498,
#  'american people': 3551,
#  'people clinton': 47122,
#  'clinton personal': 11462,
#  'personal behavior': 48110,
#  'anderson snowden': 3821,
#  'snowden lot': 59780,
#  'lot americans': 39680,
#  'americans lives': 3659,
#  'lives risk': 38783,
#  'risk snowden': 55895,
#  'snowden broke': 59777,
#  'broke law': 7920,
#  'law whistleblowers': 36641,
#  'whistleblowers run': 72346,
#  'run russia': 56217,
#  'russia try': 56333,
#  'try protection': 68023,
#  'protection putin': 51603,
#  'putin really': 51962,
#  'really believes': 52992,
#  'oh breaking': 45156,
#  'breaking ok': 7692,
#  'ok commercial': 45270,
#  'commercial break': 12221,
#  'let proposals': 37595,
#  'proposals absolutely': 51449,
#  'absolutely right': 1225,
#  'right want': 55675,
#  'want going': 70734,
#  'going happen': 26344,
#  'happen want': 28749,
#  'want revitalize': 70875,
#  'revitalize rebuild': 55238,
#  'rebuild crumbling': 53281,
#  'crumbling middle': 15183,
#  'middle class': 41855,
#  'class 30': 11124,
#  'years massive': 74275,
#  'massive redistribution': 40957,
#  'redistribution wealth': 53621,
#  'wealth know': 71963,
#  'know term': 35971,
#  'term gets': 64690,
#  'gets republican': 25722,
#  'republican friends': 54542,
#  'friends nervous': 25110,
#  'nervous problem': 44068,
#  'problem redistribution': 50827,
#  'redistribution gone': 53620,
#  'gone wrong': 26705,
#  'wrong direction': 73930,
#  'direction trillions': 18049,
#  'trillions dollars': 67644,
#  'dollars gone': 18960,
#  'gone middle': 26693,
#  'class working': 11186,
#  'working families': 73327,
#  'families tenth': 22959,
#  'tenth percent': 64673,
#  'percent doubled': 47823,
#  'doubled percentage': 19442,
#  'percentage wealth': 47954,
#  'wealth yes': 71976,
#  'yes believe': 74391,
#  'believe end': 6234,
#  'end corporate': 20799,
#  'corporate loopholes': 13722,
#  'loopholes major': 39542,
#  'major corporations': 40117,
#  'corporations year': 13766,
#  'year year': 74151,
#  'year pay': 74119,
#  'pay virtually': 46833,
#  'virtually zero': 70072,
#  'zero federal': 74613,
#  'federal income': 23353,
#  'income tax': 31666,
#  'tax stashing': 64118,
#  'stashing money': 61086,
#  'money cayman': 42538,
#  'cayman islands': 9708,
#  'islands yes': 33348,
#  'believe tax': 6400,
#  'tax wall': 64126,
#  'street speculation': 62018,
#  'speculation bailed': 60366,
#  'bailed wall': 5542,
#  'street time': 62027,
#  'time bail': 66298,
#  'bail middle': 5532,
#  'class help': 11149,
#  'help kids': 29642,
#  'kids able': 35098,
#  'able college': 995,
#  'college tuition': 11827,
#  'tuition free': 68176,
#  'free pay': 24974,
#  'pay demanding': 46753,
#  'demanding wealthiest': 16790,
#  'wealthiest people': 71982,
#  'people largest': 47396,
#  'largest corporations': 36377,
#  'corporations gotten': 13749,
#  'gotten away': 27211,
#  'away murder': 5329,
#  'murder years': 43044,
#  'years start': 74333,
#  'start paying': 60974,
#  'paying fair': 46876,
#  'fair share': 22804,
#  'think people': 65805,
#  'people region': 47558,
#  'region knew': 53930,
#  'knew failed': 35441,
#  'failed follow': 22740,
#  'follow just': 24354,
#  'just said': 34768,
#  'said rightly': 56738,
#  'rightly law': 55689,
#  'law required': 36617,
#  'required eliminated': 54692,
#  'eliminated epa': 20571,
#  'shut make': 59256,
#  'make shut': 40357,
#  'shut exists': 59252,
#  'exists right': 22088,
#  'right virtually': 55672,
#  'virtually telephone': 70066,
#  'telephone country': 64384,
#  'country ends': 14185,
#  'ends file': 20963,
#  'file nsa': 23719,
#  'nsa unacceptable': 44503,
#  'unacceptable just': 68398,
#  'just government': 34637,
#  'government surveillance': 27450,
#  'surveillance think': 63138,
#  'think government': 65677,
#  'government involved': 27358,
#  'involved mails': 32827,
#  'mails involved': 40089,
#  'involved websites': 32850,
#  'websites corporate': 72104,
#  'corporate america': 13715,
#  'america doing': 3246,
#  'doing free': 18800,
#  'free country': 24955,
#  'country right': 14397,
#  'right free': 55495,
#  'free yes': 24992,
#  'yes defend': 74404,
#  'defend terrorism': 16579,
#  'terrorism ways': 64916,
#  'ways impinging': 71877,
#  'impinging constitutional': 31233,
#  'constitutional rights': 13333,
#  'rights privacy': 55729,
#  'privacy rights': 50597,
#  'rights malley': 55727,
#  'malley anderson': 40527,
#  'anderson nsa': 3815,
#  'john honor': 34281,
#  'honor chairman': 30284,
#  'chairman senate': 9936,
#  'senate committee': 58435,
#  'committee veterans': 12302,
#  'veterans affairs': 69764,
#  'affairs years': 2234,
#  'years capacity': 74186,
#  'capacity met': 9126,
#  'met just': 41748,
#  'just extraordinary': 34610,
#  'extraordinary group': 22371,
#  'group people': 28072,
#  'people world': 47763,
#  'world war': 73689,
#  'war ii': 71132,
#  'ii korea': 30940,
#  'korea vietnam': 36184,
#  'vietnam wars': 69915,
#  'wars people': 71242,
#  'people came': 47099,
#  'came iraq': 8801,
#  'iraq afghanistan': 33022,
#  'afghanistan legs': 2317,
#  'legs arms': 37431,
#  'arms determined': 4558,
#  'determined make': 17307,
#  'make va': 40386,
#  'va health': 69261,
#  'health care': 29305,
#  'care best': 9224,
#  'best world': 6680,
#  'world expand': 73530,
#  'expand benefits': 22094,
#  'benefits men': 6538,
#  'men women': 41631,
#  'women lives': 72750,
#  'lives line': 38770,
#  'line defending': 38445,
#  'defending brought': 16593,
#  'brought legislation': 8002,
#  'legislation supported': 37397,
#  'supported american': 62795,
#  'american legion': 3529,
#  'legion vfw': 37349,
#  'vfw dod': 69845,
#  'dod vietnam': 18535,
#  'vietnam vets': 69913,
#  'vets veterans': 69833,
#  'veterans organizations': 69793,
#  'organizations comprehensive': 45776,
#  'comprehensive clearly': 12694,
#  'clearly best': 11304,
#  'best piece': 6652,
#  'piece veterans': 48292,
#  'veterans legislation': 69788,
#  'legislation brought': 37361,
#  'brought forth': 7996,
#  'forth decades': 24621,
#  'decades republican': 16303,
#  'republican votes': 54582,
#  'votes ended': 70364,
#  'ended 56': 20903,
#  '56 votes': 791,
#  'votes needed': 70374,
#  'needed 60': 43845,
#  '60 start': 805,
#  'start working': 61009,
#  'working wasn': 73404,
#  'wasn wanted': 71433,
#  'wanted sit': 71016,
#  'sit people': 59527,
#  'people like': 47410,
#  'like john': 38218,
#  'john mccain': 34291,
#  'mccain sit': 41175,
#  'like jeff': 38215,
#  'jeff miller': 33881,
#  'miller republican': 42047,
#  'republican chairman': 54525,
#  'chairman house': 9934,
#  'house work': 30604,
#  'work wasn': 73151,
#  'wanted turned': 71023,
#  'turned significant': 68274,
#  'significant pieces': 59360,
#  'pieces veterans': 48297,
#  'passed recent': 46596,
#  'recent history': 53357,
#  'history crisis': 30004,
#  'crisis lost': 15067,
#  'lost wanted': 39671,
#  'wanted stand': 71017,
#  'stand come': 60772,
#  'come best': 11904,
#  'thanks lot': 65138,
#  'executive orders': 22023,
#  'orders president': 45745,
#  'obama signed': 44829,
#  'signed president': 59342,
#  'kathie think': 34954,
#  'think kathie': 65731,
#  'absolutely fact': 1195,
#  'fact climate': 22549,
#  'change directly': 10061,
#  'directly related': 18060,
#  'related growth': 54114,
#  'growth terrorism': 28226,
#  'terrorism act': 64865,
#  'act listen': 1526,
#  'listen scientists': 38563,
#  'scientists say': 57787,
#  'say going': 57252,
#  'going countries': 26225,
#  'countries world': 14050,
#  'world cia': 73486,
#  'cia says': 10906,
#  'says going': 57583,
#  'going struggling': 26583,
#  'struggling limited': 62283,
#  'limited amounts': 38426,
#  'amounts water': 3774,
#  'water limited': 71519,
#  'amounts land': 3772,
#  'land grow': 36312,
#  'grow crops': 28115,
#  'crops ask': 15141,
#  'ask going': 4657,
#  'going kinds': 26399,
#  'kinds international': 35389,
#  'international conflict': 32576,
#  'conflict course': 12896,
#  'course international': 14600,
#  'international terrorism': 32585,
#  'terrorism major': 64893,
#  'major issue': 40136,
#  'issue got': 33558,
#  'got address': 26922,
#  'address today': 1973,
#  'today agree': 66624,
#  'agree secretary': 2603,
#  'secretary governor': 58019,
#  'governor said': 27551,
#  'said let': 56662,
#  'let area': 37480,
#  'area disagreement': 4423,
#  'disagreement secretary': 18143,
#  'secretary think': 58053,
#  'think said': 65875,
#  'said like': 56664,
#  'like bulk': 38126,
#  'bulk responsibility': 8233,
#  'responsibility fact': 54994,
#  'fact argue': 22526,
#  'argue disastrous': 4481,
#  'disastrous invasion': 18221,
#  'invasion iraq': 32684,
#  'iraq strongly': 33085,
#  'strongly opposed': 62247,
#  'opposed unraveled': 45618,
#  'unraveled region': 68967,
#  'region completely': 53916,
#  'completely led': 12632,
#  'led rise': 37190,
#  'rise al': 55832,
#  'al qaeda': 2860,
#  'qaeda isis': 52033,
#  'isis fact': 33188,
#  'fact got': 22587,
#  'got think': 27171,
#  'think widespread': 65981,
#  'widespread agreement': 72369,
#  'agreement united': 2690,
#  'states need': 61435,
#  'need lead': 43632,
#  'lead international': 36760,
#  'international coalition': 32574,
#  'coalition includes': 11672,
#  'includes significantly': 31559,
#  'significantly muslim': 59377,
#  'muslim nations': 43078,
#  'nations region': 43317,
#  'region going': 53925,
#  'going fight': 26315,
#  'fight defend': 23531,
#  'defend way': 16583,
#  'way life': 71715,
#  'lester right': 37461,
#  'right campaign': 55430,
#  'campaign meeting': 8928,
#  'meeting families': 41538,
#  'families affected': 22885,
#  'affected drug': 2242,
#  'drug problem': 19633,
#  'problem opioids': 50809,
#  'opioids heroin': 45507,
#  'heroin lives': 29762,
#  'lives lost': 38771,
#  'lost children': 39635,
#  'children orphaned': 10577,
#  'orphaned ve': 45812,
#  've met': 69548,
#  'met lot': 41749,
#  'lot grandparents': 39744,
#  'grandparents taking': 27674,
#  'taking care': 63438,
#  'care grandchildren': 9272,
#  'grandchildren tried': 27646,
#  'tried come': 67559,
#  'come comprehensive': 11911,
#  'comprehensive approach': 12692,
#  'approach number': 4298,
#  'number does': 44545,
#  'does tell': 18633,
#  'tell states': 64568,
#  'states work': 61523,
#  'work federal': 73017,
#  'federal government': 23350,
#  'government putting': 27406,
#  'putting money': 52009,
#  'money billion': 42526,
#  'billion dollars': 7029,
#  'dollars year': 19012,
#  'year help': 74094,
#  'help states': 29680,
#  'states different': 61354,
#  'different approach': 17877,
#  'approach dealing': 4286,
#  'dealing epidemic': 16020,
#  'epidemic policing': 21371,
#  'policing needs': 49039,
#  'needs change': 43883,
#  'change police': 10110,
#  'police officers': 48984,
#  'officers equipped': 45119,
#  'equipped antidote': 21401,
#  'antidote heroin': 3996,
#  'heroin overdose': 29764,
#  'overdose opioid': 45977,
#  'opioid overdose': 45506,
#  'overdose known': 45974,
#  'known narcan': 36067,
#  'narcan able': 43151,
#  'able administer': 975,
#  'administer firefighters': 1992,
#  'firefighters away': 23916,
#  'away treating': 5367,
#  'treating use': 67476,
#  'use drugs': 69069,
#  'drugs crime': 19645,
#  'crime instead': 14983,
#  'instead belongs': 32229,
#  'belongs health': 6480,
#  'health issue': 29322,
#  'issue need': 33589,
#  'need divert': 43541,
#  'divert people': 18448,
#  'people criminal': 47156,
#  'criminal justice': 15019,
#  'justice drug': 34855,
#  'drug courts': 19624,
#  'courts treatment': 14721,
#  'treatment recovery': 67489,
#  'passed state': 46601,
#  'state version': 61262,
#  'version dream': 69727,
#  'dream act': 19516,
#  'stood represented': 61689,
#  'represented constituents': 54498,
#  'constituents best': 13277,
#  'best abilities': 6602,
#  'abilities proud': 938,
#  'let just': 37559,
#  'just pick': 34732,
#  'pick point': 48237,
#  'point discussion': 48819,
#  'discussion began': 18291,
#  'began commented': 6021,
#  'commented making': 12201,
#  'making overall': 40503,
#  'overall evaluation': 45961,
#  'evaluation secretary': 21595,
#  'secretary ohio': 58034,
#  'ohio think': 45234,
#  'think september': 65890,
#  'september november': 58775,
#  'november got': 44468,
#  'got said': 27140,
#  'like beeni': 38113,
#  'beeni paraphrasing': 6015,
#  'paraphrasing criticized': 46229,
#  'criticized people': 15121,
#  'people think': 47684,
#  'think moderate': 65775,
#  'moderate moderate': 42415,
#  'moderate came': 42411,
#  'came wasn': 8848,
#  'wasn paraphrasing': 71418,
#  'paraphrasing said': 46230,
#  'said said': 56742,
#  'said wrong': 56838,
#  'wrong moderate': 73950,
#  'moderate progressive': 42417,
#  'progressive terms': 51276,
#  'terms president': 64769,
#  'obama think': 44851,
#  'think remember': 65859,
#  'remember country': 54280,
#  'country seven': 14414,
#  'seven years': 58987,
#  'years ago': 74168,
#  'ago 800': 2450,
#  '800 000': 872,
#  '000 jobs': 44,
#  'jobs lost': 34183,
#  'lost month': 39656,
#  'month trillion': 42757,
#  'trillion dollar': 67615,
#  'dollar deficit': 18920,
#  'deficit world': 16689,
#  'world financial': 73536,
#  'financial verge': 23817,
#  'verge collapse': 69685,
#  'collapse think': 11749,
#  'think president': 65824,
#  'obama vice': 44864,
#  'vice president': 69852,
#  'president biden': 50019,
#  'biden democratic': 6848,
#  'democratic leadership': 16866,
#  'leadership house': 36934,
#  'house senate': 30592,
#  'senate fantastic': 58446,
#  'fantastic job': 23069,
#  'job better': 33996,
#  'better shape': 6800,
#  'shape seven': 59026,
#  'ago republican': 2514,
#  'republican colleagues': 54526,
#  'colleagues forgotten': 11765,
#  'forgotten seven': 24581,
#  'ago fact': 2470,
#  'fact long': 22609,
#  ...}

# %%
#Train Naive Bayes Classifier
#MultinomialNB has default smoothing factor of 1
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)

# %% [markdown]
# <H3>Test the developed naive bayes classifier with "test.txt" file</H3>

# %%
X_test_dtm = vect.transform(test_df.sentence)
predicted_speaker=nb_clf.predict(X_test_dtm)

# %%
from sklearn import metrics
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.54

# %%
#Evaluate model
from sklearn import metrics
print(metrics.classification_report(test_df.speaker, predicted_speaker, target_names=test_df.speaker.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      sanders       0.75      0.20      0.32        30
#      clinton       1.00      0.19      0.32        16
#     o'malley       0.00      0.00      0.00         2
#       chafee       1.00      0.25      0.40        12
#         webb       0.58      0.58      0.58        53
#     huckabee       0.61      0.56      0.58        34
#        trump       1.00      0.20      0.33        10
#         cruz       0.00      0.00      0.00         7
#         paul       0.88      0.45      0.60        31
#     christie       1.00      0.39      0.56        18
#        rubio       1.00      0.20      0.33         5
#      fiorina       0.62      0.44      0.51        41
#       kasich       0.55      0.67      0.61        64
#         bush       0.41      0.97      0.57        71
#       carson       0.00      0.00      0.00         3
#       walker       0.00      0.00      0.00         3
#
#    micro avg       0.54      0.54      0.54       400
#    macro avg       0.59      0.32      0.36       400
# weighted avg       0.63      0.54      0.51       400
# C:\Users\anjal\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# #### 1: adding stop words

# %%
vect1 = CountVectorizer(stop_words="english") 
X_train_dtm = vect1.fit_transform(train_df.sentence)

# %%
#count of words for all speakers
vect1.vocabulary_
# Out:
# {'proud': 6233,
#  'jewish': 4406,
#  'look': 4809,
#  'father': 3161,
#  'family': 3135,
#  'wiped': 8692,
#  'hitler': 3868,
#  'holocaust': 3881,
#  'know': 4548,
#  'crazy': 1995,
#  'radical': 6337,
#  'extremist': 3089,
#  'politics': 5951,
#  'mean': 5001,
#  'learned': 4649,
#  'lesson': 4686,
#  'tiny': 8005,
#  'child': 1489,
#  'mother': 5236,
#  'shopping': 7195,
#  'people': 5779,
#  'working': 8730,
#  'stores': 7570,
#  'numbers': 5426,
#  'arms': 668,
#  'concentration': 1734,
#  'camp': 1285,
#  'essential': 2934,
#  'human': 3953,
#  'just': 4474,
#  'wasn': 8585,
#  'fact': 3105,
#  'senator': 7085,
#  'great': 3629,
#  'effort': 2718,
#  'obama': 5436,
#  'administration': 334,
#  'really': 6419,
#  'send': 7087,
#  'clear': 1569,
#  'message': 5060,
#  'knew': 4543,
#  'children': 1492,
#  'abused': 240,
#  'treated': 8125,
#  'terribly': 7905,
#  'tried': 8145,
#  'border': 1092,
#  'disagreement': 2436,
#  'think': 7948,
#  've': 8423,
#  'called': 1274,
#  'counsel': 1949,
#  'face': 3097,
#  'kind': 4527,
#  'process': 6140,
#  'speaks': 7410,
#  'advocates': 375,
#  'right': 6814,
#  'decision': 2157,
#  'hopefully': 3907,
#  'thank': 7928,
#  'anderson': 540,
#  'cnn': 1601,
#  'facebook': 3098,
#  'sponsoring': 7455,
#  'debate': 2137,
#  'america': 515,
#  'challenges': 1436,
#  'confronting': 1779,
#  'ending': 2835,
#  'perpetual': 5801,
#  'wars': 8580,
#  'addressing': 322,
#  'climate': 1580,
#  'change': 1442,
#  'income': 4109,
#  'inequality': 4161,
#  'funding': 3459,
#  'education': 2708,
#  'infrastructure': 4182,
#  'healthcare': 3790,
#  'helping': 3824,
#  'black': 1014,
#  'americans': 517,
#  'native': 5305,
#  'best': 970,
#  'able': 220,
#  'confront': 1777,
#  'served': 7117,
#  'government': 3588,
#  'levels': 4697,
#  'like': 4736,
#  'solve': 7359,
#  'problems': 6133,
#  'local': 4785,
#  'level': 4695,
#  'did': 2388,
#  'mayor': 4992,
#  'legislation': 4670,
#  'passed': 5709,
#  'congress': 1786,
#  'turn': 8197,
#  'state': 7513,
#  'governor': 3591,
#  'rhode': 6794,
#  'island': 4365,
#  '30': 114,
#  'years': 8776,
#  'public': 6256,
#  'service': 7120,
#  'scandals': 6980,
#  'high': 3841,
#  'ethical': 2944,
#  'standards': 7494,
#  'judgment': 4456,
#  'particularly': 5697,
#  'iraq': 4348,
#  'war': 8564,
#  'vote': 8520,
#  'lot': 4828,
#  'pressure': 6074,
#  'political': 5944,
#  'homework': 3886,
#  'believe': 940,
#  'evidence': 2967,
#  'saddam': 6918,
#  'hussein': 3976,
#  'weapons': 8619,
#  'mass': 4968,
#  'destruction': 2332,
#  'live': 4767,
#  'consequences': 1806,
#  'want': 8560,
#  'president': 6068,
#  'going': 3563,
#  'forward': 3394,
#  'running': 6901,
#  'end': 2828,
#  'peacemaker': 5757,
#  'proven': 6238,
#  'chafee': 1423,
#  '2016': 90,
#  'learn': 4648,
#  'let': 4689,
#  'talk': 7811,
#  'issues': 4378,
#  'bernie': 968,
#  'got': 3580,
#  'aggressively': 411,
#  'normalize': 5399,
#  'relations': 6582,
#  'iran': 4345,
#  'understanding': 8260,
#  'behavior': 929,
#  'ways': 8605,
#  'disagree': 2433,
#  'support': 7719,
#  'terrorism': 7910,
#  'anti': 567,
#  'american': 516,
#  'rhetoric': 6793,
#  'hearing': 3795,
#  'leadership': 4640,
#  'acceptable': 252,
#  'hand': 3723,
#  'managed': 4908,
#  'reach': 6397,
#  'agreement': 420,
#  'strongly': 7619,
#  'supported': 7720,
#  'prevents': 6086,
#  'getting': 3532,
#  'nuclear': 5423,
#  'weapon': 8617,
#  'seeing': 7062,
#  'fall': 3128,
#  'relationships': 6584,
#  'positive': 5985,
#  'step': 7542,
#  'question': 6318,
#  'relationship': 6583,
#  'future': 3468,
#  'yes': 8782,
#  'tell': 7880,
#  'open': 5505,
#  'embassy': 2770,
#  'tehran': 7876,
#  'tomorrow': 8023,
#  'don': 2584,
#  'goal': 3558,
#  'cuba': 2058,
#  'warm': 8568,
#  'powerful': 6007,
#  'important': 4057,
#  'country': 1960,
#  'world': 8733,
#  'true': 8165,
#  'laughter': 4617,
#  'start': 7504,
#  'providing': 6246,
#  'senate': 7084,
#  'saying': 6973,
#  'long': 4803,
#  'known': 4552,
#  '25': 104,
#  'doesn': 2569,
#  'view': 8469,
#  'need': 5323,
#  'empower': 2807,
#  'women': 8714,
#  'men': 5042,
#  'make': 4893,
#  'decisions': 2158,
#  'minds': 5109,
#  'stood': 7564,
#  'comes': 1647,
#  'lines': 4752,
#  'equal': 2905,
#  'pay': 5744,
#  'paid': 5649,
#  'leave': 4651,
#  'opportunity': 5528,
#  'far': 3147,
#  'hard': 3745,
#  'work': 8725,
#  'talent': 7807,
#  'barriers': 866,
#  'knock': 4544,
#  'core': 1922,
#  'campaign': 1286,
#  'note': 5407,
#  'historic': 3863,
#  'aside': 694,
#  'somebody': 7366,
#  'told': 8018,
#  'earlier': 2670,
#  'today': 8013,
#  '200': 72,
#  'presidential': 6069,
#  'primary': 6098,
#  'debates': 2139,
#  'time': 7996,
#  'majority': 4892,
#  'stage': 7481,
#  'll': 4773,
#  'progress': 6171,
#  'nikki': 5377,
#  'fair': 3120,
#  'flint': 3301,
#  'things': 7947,
#  'repair': 6637,
#  'weaver': 8623,
#  'program': 6169,
#  'begin': 920,
#  'help': 3821,
#  'train': 8087,
#  'distribute': 2531,
#  'water': 8595,
#  'triple': 8152,
#  'checked': 1474,
#  'regain': 6529,
#  'trust': 8172,
#  'hold': 3876,
#  'responsible': 6725,
#  'fixing': 3284,
#  'pipes': 5870,
#  'delivering': 2231,
#  'clean': 1564,
#  'said': 6926,
#  'bathe': 885,
#  'drink': 2631,
#  'wash': 8581,
#  'food': 3342,
#  'run': 6900,
#  'use': 8380,
#  'single': 7260,
#  'day': 2122,
#  'understand': 8258,
#  'pressures': 6075,
#  'real': 6411,
#  'pain': 5650,
#  'families': 3134,
#  'sure': 7733,
#  'double': 2598,
#  'check': 1473,
#  'elected': 2734,
#  'officials': 5483,
#  'senators': 7086,
#  'member': 5035,
#  'assure': 727,
#  'fixed': 3282,
#  'deserve': 2308,
#  'changes': 1445,
#  'record': 6465,
#  'toughest': 8050,
#  'comprehensive': 1725,
#  'plan': 5881,
#  'wall': 8553,
#  'street': 7593,
#  'big': 989,
#  'banks': 843,
#  'financial': 3245,
#  'interests': 4277,
#  'pose': 5979,
#  'threat': 7961,
#  'economy': 2698,
#  'bank': 835,
#  'fail': 3113,
#  'executive': 3003,
#  'jail': 4386,
#  'powers': 6009,
#  'incidentally': 4098,
#  'took': 8026,
#  'money': 5203,
#  'didn': 2389,
#  'stop': 7565,
#  'signing': 7243,
#  'law': 4623,
#  'regulations': 6552,
#  'industry': 4154,
#  'depression': 2290,
#  'democratic': 2245,
#  'nomination': 5388,
#  'united': 8303,
#  'states': 7517,
#  'good': 3571,
#  'point': 5924,
#  'virtually': 8492,
#  'general': 3507,
#  'election': 2736,
#  'match': 4977,
#  'polls': 5955,
#  'trump': 8169,
#  'secretary': 7049,
#  'clinton': 1584,
#  'sanders': 6948,
#  'better': 977,
#  'poll': 5952,
#  '20': 71,
#  'points': 5927,
#  'ahead': 426,
#  '12': 17,
#  'shock': 7186,
#  'independents': 4135,
#  'vigorous': 8475,
#  'answer': 562,
#  'page': 5647,
#  'seriously': 7112,
#  'deplorable': 2278,
#  'word': 8723,
#  'issue': 4376,
#  'malley': 4904,
#  'facing': 3104,
#  'personal': 5808,
#  'snowden': 7329,
#  'lives': 4770,
#  'risk': 6830,
#  'broke': 1175,
#  'whistleblowers': 8662,
#  'russia': 6907,
#  'try': 8178,
#  'protection': 6227,
#  'putin': 6289,
#  'believes': 943,
#  'oh': 5486,
#  'breaking': 1136,
#  'ok': 5490,
#  'commercial': 1665,
#  'break': 1133,
#  'proposals': 6209,
#  'absolutely': 233,
#  'happen': 3736,
#  'revitalize': 6780,
#  'rebuild': 6431,
#  'crumbling': 2050,
#  'middle': 5076,
#  'class': 1554,
#  'massive': 4974,
#  'redistribution': 6484,
#  'wealth': 8614,
#  'term': 7898,
#  'gets': 3531,
#  'republican': 6671,
#  'friends': 3439,
#  'nervous': 5347,
#  'problem': 6131,
#  'gone': 3569,
#  'wrong': 8760,
#  'direction': 2421,
#  'trillions': 8149,
#  'dollars': 2574,
#  'tenth': 7893,
#  'percent': 5781,
#  'doubled': 2599,
#  'percentage': 5782,
#  'corporate': 1928,
#  'loopholes': 4815,
#  'major': 4891,
#  'corporations': 1930,
#  'year': 8774,
#  'zero': 8796,
#  'federal': 3186,
#  'tax': 7846,
#  'stashing': 7512,
#  'cayman': 1389,
#  'islands': 4366,
#  'speculation': 7425,
#  'bailed': 817,
#  'bail': 816,
#  'kids': 4517,
#  'college': 1629,
#  'tuition': 8186,
#  'free': 3423,
#  'demanding': 2237,
#  'wealthiest': 8615,
#  'largest': 4601,
#  'gotten': 3583,
#  'away': 790,
#  'murder': 5266,
#  'paying': 5748,
#  'share': 7155,
#  'region': 6538,
#  'failed': 3114,
#  'follow': 3336,
#  'rightly': 6816,
#  'required': 6677,
#  'eliminated': 2751,
#  'epa': 2901,
#  'shut': 7221,
#  'exists': 3016,
#  'telephone': 7878,
#  'ends': 2843,
#  'file': 3231,
#  'nsa': 5422,
#  'unacceptable': 8224,
#  'surveillance': 7746,
#  'involved': 4338,
#  'mails': 4884,
#  'websites': 8627,
#  'doing': 2572,
#  'defend': 2189,
#  'impinging': 4047,
#  'constitutional': 1830,
#  'rights': 6817,
#  'privacy': 6115,
#  'john': 4423,
#  'honor': 3896,
#  'chairman': 1430,
#  'committee': 1674,
#  'veterans': 8444,
#  'affairs': 378,
#  'capacity': 1309,
#  'met': 5065,
#  'extraordinary': 3085,
#  'group': 3659,
#  'ii': 4001,
#  'korea': 4555,
#  'vietnam': 8468,
#  'came': 1282,
#  'afghanistan': 392,
#  'legs': 4677,
#  'determined': 2346,
#  'va': 8396,
#  'health': 3789,
#  'care': 1325,
#  'expand': 3018,
#  'benefits': 959,
#  'line': 4750,
#  'defending': 2192,
#  'brought': 1183,
#  'legion': 4668,
#  'vfw': 8451,
#  'dod': 2566,
#  'vets': 8448,
#  'organizations': 5555,
#  'clearly': 1571,
#  'piece': 5856,
#  'forth': 3388,
#  'decades': 2145,
#  'votes': 8524,
#  'ended': 2834,
#  '56': 158,
#  'needed': 5324,
#  '60': 162,
#  'wanted': 8561,
#  'sit': 7268,
#  'mccain': 4994,
#  'jeff': 4397,
#  'miller': 5099,
#  'house': 3937,
#  'turned': 8198,
#  'significant': 7241,
#  'pieces': 5857,
#  'recent': 6441,
#  'history': 3866,
#  'crisis': 2021,
#  'lost': 4827,
#  'stand': 7492,
#  'come': 1645,
#  'thanks': 7931,
#  'orders': 5549,
#  'signed': 7240,
#  'kathie': 4491,
#  'directly': 2423,
#  'related': 6579,
#  'growth': 3665,
#  'act': 290,
#  'listen': 4758,
#  'scientists': 7002,
#  'say': 6972,
#  'countries': 1959,
#  'cia': 1522,
#  'says': 6974,
#  'struggling': 7626,
#  'limited': 4744,
#  'amounts': 524,
#  'land': 4591,
#  'grow': 3661,
#  'crops': 2038,
#  'ask': 696,
#  'kinds': 4530,
#  'international': 4283,
#  'conflict': 1773,
#  'course': 1969,
#  'address': 320,
#  'agree': 416,
#  'area': 648,
#  'bulk': 1208,
#  'responsibility': 6724,
#  'argue': 654,
#  'disastrous': 2448,
#  'invasion': 4310,
#  'opposed': 5530,
#  'unraveled': 8334,
#  'completely': 1713,
#  'led': 4656,
#  'rise': 6826,
#  'al': 454,
#  'qaeda': 6294,
#  'isis': 4359,
#  'widespread': 8669,
#  'lead': 4637,
#  'coalition': 1604,
#  'includes': 4106,
#  'significantly': 7242,
#  'muslim': 5276,
#  'nations': 5303,
#  'fight': 3222,
#  'way': 8603,
#  'life': 4725,
#  'lester': 4688,
#  'meeting': 5030,
#  'affected': 380,
#  'drug': 2646,
#  'opioids': 5523,
#  'heroin': 3832,
#  'orphaned': 5565,
#  'grandparents': 3615,
#  'taking': 7806,
#  'grandchildren': 3607,
#  'approach': 624,
#  'number': 5425,
#  'does': 2568,
#  'putting': 6291,
#  'billion': 996,
#  'different': 2398,
#  'dealing': 2130,
#  'epidemic': 2902,
#  'policing': 5940,
#  'needs': 5326,
#  'police': 5936,
#  'officers': 5480,
#  'equipped': 2912,
#  'antidote': 569,
#  'overdose': 5604,
#  'opioid': 5522,
#  'narcan': 5294,
#  'administer': 332,
#  'firefighters': 3264,
#  'treating': 8126,
#  'drugs': 2647,
#  'crime': 2012,
#  'instead': 4231,
#  'belongs': 949,
#  'divert': 2543,
#  'criminal': 2015,
#  'justice': 4475,
#  'courts': 1974,
#  'treatment': 8127,
#  'recovery': 6470,
#  'version': 8438,
#  'dream': 2625,
#  'represented': 6664,
#  'constituents': 1828,
#  'abilities': 218,
#  'pick': 5846,
#  'discussion': 2475,
#  'began': 916,
#  'commented': 1662,
#  'making': 4898,
#  'overall': 5599,
#  'evaluation': 2956,
#  'ohio': 5487,
#  'september': 7108,
#  'november': 5420,
#  'beeni': 913,
#  'paraphrasing': 5678,
#  'criticized': 2029,
#  'moderate': 5184,
#  'progressive': 6172,
#  'terms': 7903,
#  'remember': 6616,
#  'seven': 7135,
#  'ago': 414,
#  '800': 187,
#  '000': 1,
#  'jobs': 4420,
#  'month': 5212,
#  'trillion': 8148,
#  'dollar': 2573,
#  'deficit': 2199,
#  'verge': 8432,
#  'collapse': 1617,
#  'vice': 8457,
#  'biden': 988,
#  'fantastic': 3145,
#  'job': 4418,
#  'shape': 7154,
#  'colleagues': 1623,
#  'forgotten': 3377,
#  'including': 4107,
#  'trade': 8071,
#  'excellent': 2983,
#  'daylight': 2124,
#  'basic': 878,
#  'premise': 6047,
#  'individual': 4148,
#  'comments': 1663,
#  'affect': 379,
#  'donations': 2587,
#  'recession': 6445,
#  'weak': 8606,
#  'disappointing': 2444,
#  '2011': 85,
#  'publicly': 6258,
#  'sought': 7384,
#  'personally': 5809,
#  'push': 6286,
#  'dodd': 2567,
#  'frank': 3417,
#  'sign': 7236,
#  'regulatory': 6554,
#  'schemes': 6991,
#  '1930s': 42,
#  'results': 6742,
#  'legitimate': 4676,
#  'answered': 563,
#  'questions': 6321,
#  'certainly': 1414,
#  'unfair': 8277,
#  'entire': 2889,
#  'picture': 5853,
#  'spent': 7435,
#  'million': 5100,
#  'taxpayer': 7852,
#  'trying': 8179,
#  'figure': 3227,
#  'protect': 6224,
#  'diplomats': 2418,
#  'benghazi': 960,
#  'wouldn': 8745,
#  'reports': 6660,
#  'pretty': 6080,
#  'obvious': 5454,
#  'story': 7573,
#  'voting': 8525,
#  'bailout': 818,
#  'billionaires': 998,
#  'destroyed': 2328,
#  'went': 8648,
#  'boys': 1115,
#  'shouldn': 7207,
#  'involvement': 4339,
#  'regime': 6536,
#  'quite': 6329,
#  'recall': 6435,
#  'times': 7998,
#  'debating': 2140,
#  'asked': 697,
#  'valued': 8415,
#  'situation': 7273,
#  'room': 6867,
#  'difficult': 2401,
#  'troops': 8155,
#  'ground': 3656,
#  'syria': 7786,
#  'worked': 8726,
#  'left': 4658,
#  'department': 2271,
#  'include': 4104,
#  'arabs': 637,
#  'worry': 8736,
#  'gaining': 3473,
#  'territory': 7908,
#  'having': 3776,
#  'frankly': 3418,
#  'posing': 5982,
#  'neighbors': 5341,
#  'talking': 7813,
#  'tough': 8048,
#  'osama': 5567,
#  'bin': 1001,
#  'laden': 4581,
#  'advisers': 369,
#  'impose': 4061,
#  'sanctions': 6945,
#  'crosstalk': 2045,
#  'export': 3063,
#  'import': 4055,
#  'boeing': 1063,
#  'corporation': 1929,
#  '40': 133,
#  'revenue': 6768,
#  'couldn': 1947,
#  'credit': 2009,
#  'lighting': 4734,
#  'young': 8788,
#  'old': 5493,
#  'everybody': 2964,
#  'sees': 7067,
#  'chance': 1440,
#  'voice': 8509,
#  'heard': 3794,
#  'happening': 3739,
#  'republicans': 6672,
#  'prevent': 6083,
#  'voices': 8512,
#  'registering': 6542,
#  'thing': 7946,
#  'quickly': 6323,
#  'deserves': 2310,
#  'washington': 8584,
#  'despite': 2320,
#  'obstructionists': 5453,
#  'understandably': 8259,
#  'reacting': 6402,
#  'fear': 3175,
#  'anxiety': 575,
#  'saw': 6970,
#  'paris': 5687,
#  'seen': 7066,
#  'san': 6943,
#  'bernardino': 967,
#  'mr': 5251,
#  'bluster': 1050,
#  'bigotry': 993,
#  'inflame': 4173,
#  'easy': 2685,
#  'answers': 565,
#  'complex': 1716,
#  'threats': 7966,
#  'focused': 3326,
#  'watching': 8594,
#  'happens': 3740,
#  'reporting': 6659,
#  'suspicious': 7758,
#  'hear': 3793,
#  'feel': 3192,
#  'marginalized': 4945,
#  'moment': 5197,
#  'funded': 3458,
#  'asking': 698,
#  'false': 3131,
#  'choice': 1500,
#  'air': 437,
#  'position': 5983,
#  'intensify': 4261,
#  'continue': 1861,
#  'build': 1203,
#  'iraqi': 4349,
#  'army': 669,
#  'success': 7667,
#  'ramadi': 6360,
#  'tribal': 8138,
#  'sheiks': 7168,
#  'anbar': 538,
#  'successful': 7669,
#  'qaida': 6295,
#  'turks': 8195,
#  'attention': 746,
#  'kurds': 4567,
#  'specific': 7414,
#  'tasks': 7842,
#  'outlining': 5579,
#  'destroying': 2329,
#  'outlined': 5578,
#  'kitchen': 4538,
#  'table': 7793,
#  'goes': 3562,
#  'possibly': 5991,
#  'accomplished': 263,
#  'husband': 3975,
#  '90s': 195,
#  'especially': 2930,
#  'raising': 6355,
#  'incomes': 4110,
#  'lifting': 4731,
#  'poverty': 6004,
#  'bet': 971,
#  'ideas': 3989,
#  'advice': 366,
#  'goodwill': 3575,
#  'emissary': 2788,
#  'solved': 7360,
#  'poor': 5962,
#  'communities': 1686,
#  'color': 1632,
#  'little': 4766,
#  'bit': 1009,
#  'happened': 3738,
#  'sandy': 6950,
#  'hook': 3902,
#  'michigan': 5074,
#  'terrible': 7904,
#  'tragedy': 8083,
#  'mentioned': 5047,
#  'killings': 4523,
#  'person': 5807,
#  'heart': 3798,
#  'broken': 1176,
#  'killing': 4522,
#  'unspeakable': 8342,
#  'lunatic': 4855,
#  'walking': 8551,
#  'maybe': 4991,
#  'gun': 3687,
#  'manufacturing': 4933,
#  'implications': 4053,
#  'rescued': 6686,
#  'auto': 770,
#  'sorry': 7380,
#  'difference': 2396,
#  'opinion': 5520,
#  'differences': 2397,
#  'fairly': 3123,
#  'deep': 2181,
#  'disagreed': 2434,
#  'listened': 4759,
#  'information': 4180,
#  'bush': 1237,
#  'cheney': 1482,
#  'voted': 8521,
#  'respect': 6709,
#  'aggressive': 410,
#  'knowing': 4549,
#  'unintended': 8296,
#  'rid': 6805,
#  'destabilized': 2324,
#  'gadhafi': 3471,
#  'dictator': 2383,
#  'created': 1998,
#  'vacuum': 8404,
#  'assad': 705,
#  'create': 1997,
#  'benefit': 957,
#  'yeah': 8773,
#  'dictators': 2385,
#  'broad': 1169,
#  'coalitions': 1605,
#  'filled': 3237,
#  'terrorists': 7912,
#  'steadily': 7532,
#  'slowly': 7308,
#  'societies': 7341,
#  'focus': 3325,
#  'secondary': 7043,
#  'anybody': 577,
#  'altar': 489,
#  'guest': 3678,
#  'worker': 8727,
#  'provisions': 6249,
#  'southern': 7394,
#  'center': 1404,
#  'talked': 7812,
#  'semi': 7083,
#  'slavery': 7293,
#  'workers': 8728,
#  'coming': 1652,
#  'conditions': 1755,
#  'thrown': 7978,
#  'reason': 6421,
#  'tom': 8021,
#  'harkin': 3753,
#  'friend': 3436,
#  'hillary': 3850,
#  'leading': 4641,
#  'labor': 4572,
#  'huge': 3949,
#  '47': 144,
#  'living': 4771,
#  'inner': 4196,
#  'cities': 1531,
#  'collapsing': 1619,
#  'germany': 3530,
#  'france': 3414,
#  'european': 2949,
#  'standard': 7493,
#  'embarrassed': 2766,
#  'stay': 7527,
#  'allies': 480,
#  'economies': 2695,
#  'defense': 2194,
#  'burden': 1218,
#  'actually': 305,
#  'started': 7505,
#  'negotiations': 5334,
#  'sending': 7088,
#  'closest': 1593,
#  'aides': 430,
#  'conversations': 1892,
#  'iranians': 4347,
#  'pleased': 5903,
#  'puts': 6290,
#  'lid': 4720,
#  'enforce': 2850,
#  'attached': 735,
#  'deal': 2128,
#  'principal': 6100,
#  'sponsor': 7453,
#  'destabilizing': 2325,
#  'governments': 3590,
#  'hezbollah': 3837,
#  'hamas': 3716,
#  'lebanon': 4654,
#  'israel': 4372,
#  'incredibly': 4125,
#  'prepared': 6052,
#  'imposing': 4063,
#  'action': 293,
#  'remove': 6626,
#  'biggest': 991,
#  'leverage': 4698,
#  'influence': 4176,
#  'iranian': 4346,
#  'reign': 6559,
#  'aggression': 409,
#  'bad': 811,
#  'haunt': 3771,
#  'adding': 317,
#  'private': 6116,
#  'insurance': 4247,
#  'businesses': 1240,
#  'average': 782,
#  'saving': 6968,
#  'thousands': 7959,
#  'jump': 4465,
#  'inaudible': 4082,
#  'wolf': 8710,
#  'programs': 6170,
#  'libyan': 4716,
#  'qadafi': 6293,
#  'demise': 2241,
#  'helped': 3822,
#  'elections': 2737,
#  'pent': 5777,
#  'desire': 2314,
#  'chart': 1465,
#  '42': 138,
#  'dictatorship': 2386,
#  'chemical': 1480,
#  'stockpile': 7559,
#  'libya': 4715,
#  'militias': 5095,
#  'terrorist': 7911,
#  'groups': 3660,
#  'set': 7126,
#  'sent': 7097,
#  'experts': 3047,
#  'offered': 5475,
#  'secure': 7058,
#  'borders': 1093,
#  'new': 5358,
#  'military': 5094,
#  'security': 7061,
#  'caught': 1382,
#  'provide': 6240,
#  'result': 6739,
#  'clash': 1553,
#  'parts': 5705,
#  'locations': 4791,
#  'walk': 8548,
#  'arab': 634,
#  'partners': 5703,
#  'business': 1239,
#  'overthrowing': 5621,
#  'small': 7309,
#  'puerto': 6261,
#  'rico': 6804,
#  '73': 179,
#  ...}

# %%
nb1_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)

# %%
X_test_dtm = vect1.transform(test_df.sentence)
predicted_speaker=nb1_clf.predict(X_test_dtm)

# %%
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.535

# %% [markdown]
# #### 2: adding bigrams

# %%
vect2 = CountVectorizer(stop_words="english",ngram_range=(2,2)) 
X_train_dtm = vect2.fit_transform(train_df.sentence)

# %%
#count of words for all speakers
vect2.vocabulary_
# Out:
# {'proud jewish': 51641,
#  'jewish jewish': 33941,
#  'jewish look': 33942,
#  'look father': 39264,
#  'father family': 23206,
#  'family wiped': 23052,
#  'wiped hitler': 72572,
#  'hitler holocaust': 30072,
#  'holocaust know': 30129,
#  'know crazy': 35582,
#  'crazy radical': 14782,
#  'radical extremist': 52388,
#  'extremist politics': 22395,
#  'politics mean': 49299,
#  'mean learned': 41233,
#  'learned lesson': 37058,
#  'lesson tiny': 37451,
#  'tiny tiny': 66596,
#  'tiny child': 66595,
#  'child mother': 10483,
#  'mother shopping': 42902,
#  'shopping people': 59136,
#  'people working': 47762,
#  'working stores': 73389,
#  'stores numbers': 61789,
#  'numbers arms': 44636,
#  'arms hitler': 4560,
#  'hitler concentration': 30071,
#  'concentration camp': 12729,
#  'camp proud': 8862,
#  'jewish essential': 33940,
#  'essential human': 21478,
#  'just wasn': 34826,
#  'wasn just': 71408,
#  'wasn fact': 71400,
#  'fact senator': 22648,
#  'senator fact': 58519,
#  'fact great': 22589,
#  'great effort': 27748,
#  'effort obama': 20315,
#  'obama administration': 44680,
#  'administration really': 2050,
#  'really send': 53096,
#  'send clear': 58586,
#  'clear message': 11270,
#  'message knew': 41723,
#  'knew children': 35437,
#  'children abused': 10509,
#  'abused treated': 1277,
#  'treated terribly': 67469,
#  'terribly tried': 64830,
#  'tried border': 67556,
#  'border disagreement': 7473,
#  'disagreement think': 18144,
#  'think ve': 65962,
#  've called': 69423,
#  'called counsel': 8657,
#  'counsel child': 13947,
#  'child child': 10458,
#  'child face': 10466,
#  'face kind': 22443,
#  'kind process': 35349,
#  'process speaks': 51029,
#  'speaks advocates': 60288,
#  'advocates child': 2220,
#  'child right': 10491,
#  'right decision': 55459,
#  'decision hopefully': 16382,
#  'thank anderson': 65053,
#  'anderson thank': 3825,
#  'thank cnn': 65062,
#  'cnn thank': 11637,
#  'thank facebook': 65072,
#  'facebook sponsoring': 22468,
#  'sponsoring debate': 60578,
#  'debate america': 16121,
#  'america challenges': 3213,
#  'challenges confronting': 9966,
#  'confronting ending': 12929,
#  'ending perpetual': 20923,
#  'perpetual wars': 48015,
#  'wars addressing': 71229,
#  'addressing climate': 1978,
#  'climate change': 11344,
#  'change addressing': 10038,
#  'addressing income': 1979,
#  'income inequality': 31645,
#  'inequality funding': 31994,
#  'funding education': 25247,
#  'education funding': 20192,
#  'funding infrastructure': 25254,
#  'infrastructure funding': 32089,
#  'funding healthcare': 25252,
#  'healthcare helping': 29346,
#  'helping black': 29722,
#  'black americans': 7207,
#  'americans helping': 3638,
#  'helping native': 29727,
#  'native americans': 43325,
#  'americans challenges': 3607,
#  'challenges best': 9965,
#  'best able': 6604,
#  'able confront': 998,
#  'confront challenges': 12911,
#  'challenges ve': 9977,
#  've served': 69607,
#  'served government': 58819,
#  'government levels': 27366,
#  'levels know': 37716,
#  'know like': 35761,
#  'like solve': 38352,
#  'solve problems': 59931,
#  'problems local': 50915,
#  'local level': 39054,
#  'level did': 37670,
#  'did mayor': 17576,
#  'mayor know': 41156,
#  'know legislation': 35756,
#  'legislation passed': 37384,
#  'passed congress': 46580,
#  'congress did': 12966,
#  'did senator': 17623,
#  'senator know': 58531,
#  'know turn': 35995,
#  'turn state': 68250,
#  'state did': 61130,
#  'did governor': 17527,
#  'governor rhode': 27549,
#  'rhode island': 55283,
#  'island proud': 33342,
#  'proud 30': 51616,
#  '30 years': 636,
#  'years public': 74302,
#  'public service': 51829,
#  'service scandals': 58850,
#  'scandals high': 57652,
#  'high ethical': 29806,
#  'ethical standards': 21528,
#  'standards proud': 60864,
#  'proud judgment': 51644,
#  'judgment particularly': 34446,
#  'particularly iraq': 46381,
#  'iraq war': 33096,
#  'war vote': 71184,
#  'vote lot': 70207,
#  'lot pressure': 39800,
#  'pressure political': 50347,
#  'political pressure': 49187,
#  'pressure public': 50348,
#  'public pressure': 51817,
#  'pressure did': 50342,
#  'did homework': 17541,
#  'homework did': 30229,
#  'did believe': 17457,
#  'believe evidence': 6238,
#  'evidence saddam': 21763,
#  'saddam hussein': 56403,
#  'hussein weapons': 30798,
#  'weapons mass': 72049,
#  'mass destruction': 40925,
#  'destruction live': 17272,
#  'live consequences': 38688,
#  'consequences kind': 13129,
#  'kind judgment': 35321,
#  'judgment want': 34462,
#  'want president': 70842,
#  'president going': 50110,
#  'going forward': 26330,
#  'forward running': 24725,
#  'running president': 56256,
#  'president end': 50081,
#  'end wars': 20889,
#  'wars want': 71248,
#  'want peacemaker': 70828,
#  'peacemaker proven': 46966,
#  'proven peacemaker': 51693,
#  'peacemaker chafee': 46965,
#  'chafee 2016': 9917,
#  '2016 learn': 526,
#  'learn thank': 37043,
#  'let talk': 37628,
#  'talk issues': 63582,
#  'thank bernie': 65059,
#  'bernie thank': 6600,
#  've got': 69491,
#  'got aggressively': 26926,
#  'aggressively normalize': 2443,
#  'normalize relations': 44396,
#  'relations iran': 54132,
#  'iran understanding': 32985,
#  'understanding iran': 68633,
#  'iran behavior': 32898,
#  'behavior ways': 6140,
#  'ways disagree': 71869,
#  'disagree support': 18125,
#  'support terrorism': 62774,
#  'terrorism anti': 64866,
#  'anti american': 3984,
#  'american rhetoric': 3566,
#  'rhetoric hearing': 55279,
#  'hearing leadership': 29474,
#  'leadership acceptable': 36906,
#  'acceptable hand': 1309,
#  'hand fact': 28616,
#  'fact ve': 22672,
#  've managed': 69541,
#  'managed reach': 40606,
#  'reach agreement': 52713,
#  'agreement ve': 2691,
#  've strongly': 69624,
#  'strongly supported': 62254,
#  'supported prevents': 62836,
#  'prevents iran': 50416,
#  'iran getting': 32925,
#  'getting nuclear': 25794,
#  'nuclear weapon': 44527,
#  'weapon did': 72006,
#  'did going': 17525,
#  'going war': 26636,
#  'war believe': 71105,
#  'believe seeing': 6378,
#  'seeing fall': 58247,
#  'fall relationships': 22855,
#  'relationships iran': 54164,
#  'iran positive': 32950,
#  'positive step': 49544,
#  'step question': 61616,
#  'question want': 52209,
#  'want relationship': 70865,
#  'relationship positive': 54154,
#  'positive future': 49536,
#  'future yes': 25352,
#  'yes tell': 74477,
#  'tell open': 64527,
#  'open embassy': 45423,
#  'embassy tehran': 20615,
#  'tehran tomorrow': 64381,
#  'tomorrow don': 66839,
#  'don think': 19263,
#  'think think': 65935,
#  'think goal': 65671,
#  'goal ve': 26031,
#  've cuba': 69440,
#  'cuba warm': 15245,
#  'warm relations': 71207,
#  'relations powerful': 54137,
#  'powerful important': 49789,
#  'important country': 31276,
#  'country world': 14507,
#  'true laughter': 67741,
#  'start providing': 60977,
#  'providing senate': 51765,
#  'look think': 39415,
#  'think saying': 65879,
#  'saying long': 57511,
#  'long ve': 39133,
#  've known': 69519,
#  'known 25': 36056,
#  '25 years': 595,
#  'years doesn': 74216,
#  'doesn change': 18662,
#  'change view': 10146,
#  'view need': 69937,
#  'need empower': 43552,
#  'empower women': 20728,
#  'women men': 72756,
#  'men make': 41621,
#  'make best': 40203,
#  'best decisions': 6620,
#  'decisions minds': 16424,
#  'minds make': 42177,
#  'make ve': 40387,
#  've stood': 69622,
#  'stood comes': 61667,
#  'comes issues': 12064,
#  'issues really': 33712,
#  'really lines': 53061,
#  'lines going': 38491,
#  'going equal': 26294,
#  'equal pay': 21379,
#  'pay paid': 46799,
#  'paid family': 46141,
#  'family leave': 23015,
#  'leave opportunity': 37109,
#  'opportunity know': 45558,
#  'know women': 36032,
#  'women far': 72737,
#  'far hard': 23108,
#  'hard work': 29017,
#  'work talent': 73132,
#  'talent think': 63488,
#  'think barriers': 65545,
#  'barriers knock': 5795,
#  'knock core': 35460,
#  'core campaign': 13691,
#  'campaign note': 8930,
#  'note just': 44421,
#  'just historic': 34653,
#  'historic aside': 29983,
#  'aside somebody': 4642,
#  'somebody told': 60026,
#  'told earlier': 66794,
#  'earlier today': 19746,
#  'today ve': 66761,
#  've like': 69531,
#  'like 200': 38086,
#  '200 presidential': 424,
#  'presidential primary': 50319,
#  'primary debates': 50476,
#  'debates time': 16207,
#  'time majority': 66405,
#  'majority women': 40177,
#  'women stage': 72772,
#  'stage know': 60678,
#  'know ll': 35766,
#  'll progress': 38937,
#  'nikki fair': 44275,
#  'fair question': 22796,
#  'question government': 52140,
#  'levels let': 37717,
#  'let children': 37495,
#  'children people': 10580,
#  'people flint': 47266,
#  'flint think': 24088,
#  'think things': 65934,
#  'things repair': 65457,
#  'repair work': 54370,
#  'work mayor': 73065,
#  'mayor weaver': 41165,
#  'weaver program': 72085,
#  'program support': 51187,
#  'support begin': 62643,
#  'begin help': 6054,
#  'help train': 29686,
#  'train people': 67335,
#  'flint able': 24067,
#  'able work': 1106,
#  'work distribute': 73003,
#  'distribute water': 18428,
#  'water triple': 71531,
#  'triple checked': 67652,
#  'checked regain': 10339,
#  'regain trust': 53871,
#  'trust hold': 67897,
#  'hold responsible': 30096,
#  'responsible fixing': 55024,
#  'fixing pipes': 24012,
#  'pipes delivering': 48321,
#  'delivering clean': 16775,
#  'clean water': 11218,
#  'water said': 71526,
#  'said bathe': 56532,
#  'bathe drink': 5915,
#  'drink wash': 19552,
#  'wash food': 71250,
#  'food run': 24392,
#  'run minds': 56207,
#  'minds use': 42178,
#  'use water': 69130,
#  'water single': 71527,
#  'single day': 59461,
#  'day understand': 15760,
#  'understand pressures': 68568,
#  'pressures real': 50354,
#  'real pain': 52924,
#  'pain families': 46158,
#  'families going': 22916,
#  'going make': 26430,
#  'make sure': 40370,
#  'sure president': 63047,
#  'president double': 50078,
#  'double triple': 19438,
#  'triple check': 67651,
#  'check work': 10337,
#  'work elected': 73011,
#  'elected officials': 20428,
#  'officials trust': 45146,
#  'trust like': 67900,
#  'like mayor': 38255,
#  'mayor like': 41157,
#  'like senators': 38344,
#  'senators member': 58571,
#  'member congress': 41575,
#  'congress assure': 12950,
#  'assure fixed': 4953,
#  'fixed trust': 24002,
#  'trust deserve': 67891,
#  'called changes': 8650,
#  'changes record': 10202,
#  'record toughest': 53564,
#  'toughest comprehensive': 67169,
#  'comprehensive plan': 12703,
#  'plan wall': 48581,
#  'wall street': 70592,
#  'street just': 61983,
#  'just big': 34540,
#  'big banks': 6858,
#  'banks financial': 5706,
#  'financial interests': 23805,
#  'interests pose': 32552,
#  'pose threat': 49448,
#  'threat economy': 66147,
#  'economy said': 20127,
#  'said bank': 56529,
#  'bank big': 5631,
#  'big fail': 6892,
#  'fail executive': 22724,
#  'executive powerful': 22026,
#  'powerful jail': 49793,
#  'jail use': 33778,
#  'use powers': 69108,
#  'powers passed': 49815,
#  'congress president': 13006,
#  'president obama': 50172,
#  'obama incidentally': 44760,
#  'incidentally took': 31535,
#  'took lot': 66981,
#  'lot money': 39780,
#  'money wall': 42722,
#  'street didn': 61947,
#  'didn stop': 17768,
#  'stop signing': 61754,
#  'signing law': 59384,
#  'law toughest': 36634,
#  'toughest regulations': 67174,
#  'regulations financial': 54009,
#  'financial industry': 23802,
#  'industry great': 31949,
#  'great depression': 27741,
#  'running democratic': 56239,
#  'democratic nomination': 16869,
#  'nomination president': 44328,
#  'president united': 50280,
#  'united states': 68844,
#  'states good': 61385,
#  'good point': 26829,
#  'point know': 48845,
#  'know virtually': 36010,
#  'virtually general': 70055,
#  'general election': 25557,
#  'election match': 20487,
#  'match polls': 40972,
#  'polls trump': 49364,
#  'trump secretary': 67853,
#  'secretary clinton': 58003,
#  'clinton trump': 11523,
#  'trump bernie': 67794,
#  'bernie sanders': 6597,
#  'sanders polls': 56949,
#  'polls better': 49344,
#  'better secretary': 6798,
#  'clinton cnn': 11387,
#  'cnn poll': 11632,
#  'poll 20': 49315,
#  '20 points': 414,
#  'points ahead': 48922,
#  'ahead trump': 2755,
#  'trump think': 67862,
#  'think secretary': 65882,
#  'clinton 12': 11357,
#  '12 points': 230,
#  'points know': 48938,
#  'know fact': 35643,
#  'fact lot': 22610,
#  'lot people': 39792,
#  'people shock': 47612,
#  'shock secretary': 59106,
#  'secretary lot': 58026,
#  'lot independents': 39757,
#  'independents country': 31846,
#  'supported know': 62825,
#  'know vigorous': 36009,
#  'vigorous agreement': 69977,
#  'agreement senator': 2681,
#  'don answer': 19060,
#  'answer page': 3941,
#  'page yes': 46119,
#  'yes laughter': 74433,
#  'laughter mean': 36492,
#  'mean seriously': 41262,
#  'seriously know': 58792,
#  'know ve': 36006,
#  've yes': 69670,
#  'yes behavior': 74390,
#  'behavior deplorable': 6129,
#  'deplorable said': 17046,
#  'said word': 56830,
#  'word issue': 72908,
#  'issue going': 33557,
#  'going debate': 26238,
#  'debate secretary': 16174,
#  'clinton governor': 11427,
#  'governor malley': 27533,
#  'malley issues': 40532,
#  'issues facing': 33672,
#  'facing american': 22498,
#  'american people': 3551,
#  'people clinton': 47122,
#  'clinton personal': 11462,
#  'personal behavior': 48110,
#  'anderson snowden': 3821,
#  'snowden lot': 59780,
#  'lot americans': 39680,
#  'americans lives': 3659,
#  'lives risk': 38783,
#  'risk snowden': 55895,
#  'snowden broke': 59777,
#  'broke law': 7920,
#  'law whistleblowers': 36641,
#  'whistleblowers run': 72346,
#  'run russia': 56217,
#  'russia try': 56333,
#  'try protection': 68023,
#  'protection putin': 51603,
#  'putin really': 51962,
#  'really believes': 52992,
#  'oh breaking': 45156,
#  'breaking ok': 7692,
#  'ok commercial': 45270,
#  'commercial break': 12221,
#  'let proposals': 37595,
#  'proposals absolutely': 51449,
#  'absolutely right': 1225,
#  'right want': 55675,
#  'want going': 70734,
#  'going happen': 26344,
#  'happen want': 28749,
#  'want revitalize': 70875,
#  'revitalize rebuild': 55238,
#  'rebuild crumbling': 53281,
#  'crumbling middle': 15183,
#  'middle class': 41855,
#  'class 30': 11124,
#  'years massive': 74275,
#  'massive redistribution': 40957,
#  'redistribution wealth': 53621,
#  'wealth know': 71963,
#  'know term': 35971,
#  'term gets': 64690,
#  'gets republican': 25722,
#  'republican friends': 54542,
#  'friends nervous': 25110,
#  'nervous problem': 44068,
#  'problem redistribution': 50827,
#  'redistribution gone': 53620,
#  'gone wrong': 26705,
#  'wrong direction': 73930,
#  'direction trillions': 18049,
#  'trillions dollars': 67644,
#  'dollars gone': 18960,
#  'gone middle': 26693,
#  'class working': 11186,
#  'working families': 73327,
#  'families tenth': 22959,
#  'tenth percent': 64673,
#  'percent doubled': 47823,
#  'doubled percentage': 19442,
#  'percentage wealth': 47954,
#  'wealth yes': 71976,
#  'yes believe': 74391,
#  'believe end': 6234,
#  'end corporate': 20799,
#  'corporate loopholes': 13722,
#  'loopholes major': 39542,
#  'major corporations': 40117,
#  'corporations year': 13766,
#  'year year': 74151,
#  'year pay': 74119,
#  'pay virtually': 46833,
#  'virtually zero': 70072,
#  'zero federal': 74613,
#  'federal income': 23353,
#  'income tax': 31666,
#  'tax stashing': 64118,
#  'stashing money': 61086,
#  'money cayman': 42538,
#  'cayman islands': 9708,
#  'islands yes': 33348,
#  'believe tax': 6400,
#  'tax wall': 64126,
#  'street speculation': 62018,
#  'speculation bailed': 60366,
#  'bailed wall': 5542,
#  'street time': 62027,
#  'time bail': 66298,
#  'bail middle': 5532,
#  'class help': 11149,
#  'help kids': 29642,
#  'kids able': 35098,
#  'able college': 995,
#  'college tuition': 11827,
#  'tuition free': 68176,
#  'free pay': 24974,
#  'pay demanding': 46753,
#  'demanding wealthiest': 16790,
#  'wealthiest people': 71982,
#  'people largest': 47396,
#  'largest corporations': 36377,
#  'corporations gotten': 13749,
#  'gotten away': 27211,
#  'away murder': 5329,
#  'murder years': 43044,
#  'years start': 74333,
#  'start paying': 60974,
#  'paying fair': 46876,
#  'fair share': 22804,
#  'think people': 65805,
#  'people region': 47558,
#  'region knew': 53930,
#  'knew failed': 35441,
#  'failed follow': 22740,
#  'follow just': 24354,
#  'just said': 34768,
#  'said rightly': 56738,
#  'rightly law': 55689,
#  'law required': 36617,
#  'required eliminated': 54692,
#  'eliminated epa': 20571,
#  'shut make': 59256,
#  'make shut': 40357,
#  'shut exists': 59252,
#  'exists right': 22088,
#  'right virtually': 55672,
#  'virtually telephone': 70066,
#  'telephone country': 64384,
#  'country ends': 14185,
#  'ends file': 20963,
#  'file nsa': 23719,
#  'nsa unacceptable': 44503,
#  'unacceptable just': 68398,
#  'just government': 34637,
#  'government surveillance': 27450,
#  'surveillance think': 63138,
#  'think government': 65677,
#  'government involved': 27358,
#  'involved mails': 32827,
#  'mails involved': 40089,
#  'involved websites': 32850,
#  'websites corporate': 72104,
#  'corporate america': 13715,
#  'america doing': 3246,
#  'doing free': 18800,
#  'free country': 24955,
#  'country right': 14397,
#  'right free': 55495,
#  'free yes': 24992,
#  'yes defend': 74404,
#  'defend terrorism': 16579,
#  'terrorism ways': 64916,
#  'ways impinging': 71877,
#  'impinging constitutional': 31233,
#  'constitutional rights': 13333,
#  'rights privacy': 55729,
#  'privacy rights': 50597,
#  'rights malley': 55727,
#  'malley anderson': 40527,
#  'anderson nsa': 3815,
#  'john honor': 34281,
#  'honor chairman': 30284,
#  'chairman senate': 9936,
#  'senate committee': 58435,
#  'committee veterans': 12302,
#  'veterans affairs': 69764,
#  'affairs years': 2234,
#  'years capacity': 74186,
#  'capacity met': 9126,
#  'met just': 41748,
#  'just extraordinary': 34610,
#  'extraordinary group': 22371,
#  'group people': 28072,
#  'people world': 47763,
#  'world war': 73689,
#  'war ii': 71132,
#  'ii korea': 30940,
#  'korea vietnam': 36184,
#  'vietnam wars': 69915,
#  'wars people': 71242,
#  'people came': 47099,
#  'came iraq': 8801,
#  'iraq afghanistan': 33022,
#  'afghanistan legs': 2317,
#  'legs arms': 37431,
#  'arms determined': 4558,
#  'determined make': 17307,
#  'make va': 40386,
#  'va health': 69261,
#  'health care': 29305,
#  'care best': 9224,
#  'best world': 6680,
#  'world expand': 73530,
#  'expand benefits': 22094,
#  'benefits men': 6538,
#  'men women': 41631,
#  'women lives': 72750,
#  'lives line': 38770,
#  'line defending': 38445,
#  'defending brought': 16593,
#  'brought legislation': 8002,
#  'legislation supported': 37397,
#  'supported american': 62795,
#  'american legion': 3529,
#  'legion vfw': 37349,
#  'vfw dod': 69845,
#  'dod vietnam': 18535,
#  'vietnam vets': 69913,
#  'vets veterans': 69833,
#  'veterans organizations': 69793,
#  'organizations comprehensive': 45776,
#  'comprehensive clearly': 12694,
#  'clearly best': 11304,
#  'best piece': 6652,
#  'piece veterans': 48292,
#  'veterans legislation': 69788,
#  'legislation brought': 37361,
#  'brought forth': 7996,
#  'forth decades': 24621,
#  'decades republican': 16303,
#  'republican votes': 54582,
#  'votes ended': 70364,
#  'ended 56': 20903,
#  '56 votes': 791,
#  'votes needed': 70374,
#  'needed 60': 43845,
#  '60 start': 805,
#  'start working': 61009,
#  'working wasn': 73404,
#  'wasn wanted': 71433,
#  'wanted sit': 71016,
#  'sit people': 59527,
#  'people like': 47410,
#  'like john': 38218,
#  'john mccain': 34291,
#  'mccain sit': 41175,
#  'like jeff': 38215,
#  'jeff miller': 33881,
#  'miller republican': 42047,
#  'republican chairman': 54525,
#  'chairman house': 9934,
#  'house work': 30604,
#  'work wasn': 73151,
#  'wanted turned': 71023,
#  'turned significant': 68274,
#  'significant pieces': 59360,
#  'pieces veterans': 48297,
#  'passed recent': 46596,
#  'recent history': 53357,
#  'history crisis': 30004,
#  'crisis lost': 15067,
#  'lost wanted': 39671,
#  'wanted stand': 71017,
#  'stand come': 60772,
#  'come best': 11904,
#  'thanks lot': 65138,
#  'executive orders': 22023,
#  'orders president': 45745,
#  'obama signed': 44829,
#  'signed president': 59342,
#  'kathie think': 34954,
#  'think kathie': 65731,
#  'absolutely fact': 1195,
#  'fact climate': 22549,
#  'change directly': 10061,
#  'directly related': 18060,
#  'related growth': 54114,
#  'growth terrorism': 28226,
#  'terrorism act': 64865,
#  'act listen': 1526,
#  'listen scientists': 38563,
#  'scientists say': 57787,
#  'say going': 57252,
#  'going countries': 26225,
#  'countries world': 14050,
#  'world cia': 73486,
#  'cia says': 10906,
#  'says going': 57583,
#  'going struggling': 26583,
#  'struggling limited': 62283,
#  'limited amounts': 38426,
#  'amounts water': 3774,
#  'water limited': 71519,
#  'amounts land': 3772,
#  'land grow': 36312,
#  'grow crops': 28115,
#  'crops ask': 15141,
#  'ask going': 4657,
#  'going kinds': 26399,
#  'kinds international': 35389,
#  'international conflict': 32576,
#  'conflict course': 12896,
#  'course international': 14600,
#  'international terrorism': 32585,
#  'terrorism major': 64893,
#  'major issue': 40136,
#  'issue got': 33558,
#  'got address': 26922,
#  'address today': 1973,
#  'today agree': 66624,
#  'agree secretary': 2603,
#  'secretary governor': 58019,
#  'governor said': 27551,
#  'said let': 56662,
#  'let area': 37480,
#  'area disagreement': 4423,
#  'disagreement secretary': 18143,
#  'secretary think': 58053,
#  'think said': 65875,
#  'said like': 56664,
#  'like bulk': 38126,
#  'bulk responsibility': 8233,
#  'responsibility fact': 54994,
#  'fact argue': 22526,
#  'argue disastrous': 4481,
#  'disastrous invasion': 18221,
#  'invasion iraq': 32684,
#  'iraq strongly': 33085,
#  'strongly opposed': 62247,
#  'opposed unraveled': 45618,
#  'unraveled region': 68967,
#  'region completely': 53916,
#  'completely led': 12632,
#  'led rise': 37190,
#  'rise al': 55832,
#  'al qaeda': 2860,
#  'qaeda isis': 52033,
#  'isis fact': 33188,
#  'fact got': 22587,
#  'got think': 27171,
#  'think widespread': 65981,
#  'widespread agreement': 72369,
#  'agreement united': 2690,
#  'states need': 61435,
#  'need lead': 43632,
#  'lead international': 36760,
#  'international coalition': 32574,
#  'coalition includes': 11672,
#  'includes significantly': 31559,
#  'significantly muslim': 59377,
#  'muslim nations': 43078,
#  'nations region': 43317,
#  'region going': 53925,
#  'going fight': 26315,
#  'fight defend': 23531,
#  'defend way': 16583,
#  'way life': 71715,
#  'lester right': 37461,
#  'right campaign': 55430,
#  'campaign meeting': 8928,
#  'meeting families': 41538,
#  'families affected': 22885,
#  'affected drug': 2242,
#  'drug problem': 19633,
#  'problem opioids': 50809,
#  'opioids heroin': 45507,
#  'heroin lives': 29762,
#  'lives lost': 38771,
#  'lost children': 39635,
#  'children orphaned': 10577,
#  'orphaned ve': 45812,
#  've met': 69548,
#  'met lot': 41749,
#  'lot grandparents': 39744,
#  'grandparents taking': 27674,
#  'taking care': 63438,
#  'care grandchildren': 9272,
#  'grandchildren tried': 27646,
#  'tried come': 67559,
#  'come comprehensive': 11911,
#  'comprehensive approach': 12692,
#  'approach number': 4298,
#  'number does': 44545,
#  'does tell': 18633,
#  'tell states': 64568,
#  'states work': 61523,
#  'work federal': 73017,
#  'federal government': 23350,
#  'government putting': 27406,
#  'putting money': 52009,
#  'money billion': 42526,
#  'billion dollars': 7029,
#  'dollars year': 19012,
#  'year help': 74094,
#  'help states': 29680,
#  'states different': 61354,
#  'different approach': 17877,
#  'approach dealing': 4286,
#  'dealing epidemic': 16020,
#  'epidemic policing': 21371,
#  'policing needs': 49039,
#  'needs change': 43883,
#  'change police': 10110,
#  'police officers': 48984,
#  'officers equipped': 45119,
#  'equipped antidote': 21401,
#  'antidote heroin': 3996,
#  'heroin overdose': 29764,
#  'overdose opioid': 45977,
#  'opioid overdose': 45506,
#  'overdose known': 45974,
#  'known narcan': 36067,
#  'narcan able': 43151,
#  'able administer': 975,
#  'administer firefighters': 1992,
#  'firefighters away': 23916,
#  'away treating': 5367,
#  'treating use': 67476,
#  'use drugs': 69069,
#  'drugs crime': 19645,
#  'crime instead': 14983,
#  'instead belongs': 32229,
#  'belongs health': 6480,
#  'health issue': 29322,
#  'issue need': 33589,
#  'need divert': 43541,
#  'divert people': 18448,
#  'people criminal': 47156,
#  'criminal justice': 15019,
#  'justice drug': 34855,
#  'drug courts': 19624,
#  'courts treatment': 14721,
#  'treatment recovery': 67489,
#  'passed state': 46601,
#  'state version': 61262,
#  'version dream': 69727,
#  'dream act': 19516,
#  'stood represented': 61689,
#  'represented constituents': 54498,
#  'constituents best': 13277,
#  'best abilities': 6602,
#  'abilities proud': 938,
#  'let just': 37559,
#  'just pick': 34732,
#  'pick point': 48237,
#  'point discussion': 48819,
#  'discussion began': 18291,
#  'began commented': 6021,
#  'commented making': 12201,
#  'making overall': 40503,
#  'overall evaluation': 45961,
#  'evaluation secretary': 21595,
#  'secretary ohio': 58034,
#  'ohio think': 45234,
#  'think september': 65890,
#  'september november': 58775,
#  'november got': 44468,
#  'got said': 27140,
#  'like beeni': 38113,
#  'beeni paraphrasing': 6015,
#  'paraphrasing criticized': 46229,
#  'criticized people': 15121,
#  'people think': 47684,
#  'think moderate': 65775,
#  'moderate moderate': 42415,
#  'moderate came': 42411,
#  'came wasn': 8848,
#  'wasn paraphrasing': 71418,
#  'paraphrasing said': 46230,
#  'said said': 56742,
#  'said wrong': 56838,
#  'wrong moderate': 73950,
#  'moderate progressive': 42417,
#  'progressive terms': 51276,
#  'terms president': 64769,
#  'obama think': 44851,
#  'think remember': 65859,
#  'remember country': 54280,
#  'country seven': 14414,
#  'seven years': 58987,
#  'years ago': 74168,
#  'ago 800': 2450,
#  '800 000': 872,
#  '000 jobs': 44,
#  'jobs lost': 34183,
#  'lost month': 39656,
#  'month trillion': 42757,
#  'trillion dollar': 67615,
#  'dollar deficit': 18920,
#  'deficit world': 16689,
#  'world financial': 73536,
#  'financial verge': 23817,
#  'verge collapse': 69685,
#  'collapse think': 11749,
#  'think president': 65824,
#  'obama vice': 44864,
#  'vice president': 69852,
#  'president biden': 50019,
#  'biden democratic': 6848,
#  'democratic leadership': 16866,
#  'leadership house': 36934,
#  'house senate': 30592,
#  'senate fantastic': 58446,
#  'fantastic job': 23069,
#  'job better': 33996,
#  'better shape': 6800,
#  'shape seven': 59026,
#  'ago republican': 2514,
#  'republican colleagues': 54526,
#  'colleagues forgotten': 11765,
#  'forgotten seven': 24581,
#  'ago fact': 2470,
#  'fact long': 22609,
#  ...}

# %%
nb2_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)

# %%
X_test_dtm = vect2.transform(test_df.sentence)
predicted_speaker=nb2_clf.predict(X_test_dtm)

# %%
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.54

# %% [markdown]
# I used  "stop_words" and "bi_grams" as my additional 2 features and the accuracy increased to 54%. This indicated that model is more accurate when it tries to predict based on 2 prior words. Also the accuracy decreases if I choose tri grams because of smal document size.
